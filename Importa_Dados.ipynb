# %%
import pandas as pd

#raw=true -> baixa de forma buta(normal), sem formatação
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
dados.head() #mostrar apenas a parte superior
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
dados.tail() #mostrar apenas a parte inferior
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %%
dados.shape #mostra a quantidade de linhas e colunas
# Out:
# (23814, 877)

# %%
dados['tratamento'] #seleciona apenas a coluna solicitada, mostrando todos os dados nela
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #seleciona a coluna solicitada mostrando os tipos que ela tem
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# Com droga, como o próprio nome nos diz, é quando estamos aplicando algum tipo de droga para a amostra. Já com o controle é uma técnica estatística em que isolamos as outras varíaveis e observamos apenas a variável de interesse.

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48], dtype=int64)

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: 24, 72 e 48. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Temos dois tipos de doses diferentes, d1 e d2, mas não conseguimos afirmar nada categoricamente de antemão.

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Agora com a resposta de ```dados['droga'].unique()``` obtivemos essa série de códigos como resposta. Talvez esses números foram codificados na tentativa de anonimizar os tipos de drogas usadas, para tentar evitar qualquer tipo de viés na análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita, para que sejam evitados vieses.

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts() #mostra a quantidade de cada tipo na tabela
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True) #mostra a quantidade normalizada
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True).map('{:.2%}'.format) #map formata para tornar os valores em porcentagem
# Out:
# D1    51.01%
# D2    48.99%
# Name: dose, dtype: object

# %%
dados['tratamento'].value_counts().plot.pie() #plot(plotar gráfico),pie(tipo pedaço=pizza)
plt.show()

# %%
dados['tempo'].value_counts().plot.pie()
plt.show()

# %%
dados['tempo'].value_counts().plot.bar() #gráfico de barra
plt.show()

# %%
dados['g-0'] > 0 #uma condição para filtrar todos resultados acima de zero
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_filtrados = dados[dados['g-0']>0] #guardar a condição na tabela original em uma variável nova
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 6  id_001bd861f  com_droga     24   D2  746ca1f5a  2.0440  1.7000 -1.5390
# 7  id_0020d0484  com_droga     48   D1  8b87a7a83  0.2711  0.5133 -0.1327
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 6  5.9440 -2.1670  ...  0.1855  1.1720  0.8325  0.6486  0.8090  1.5880
# 7  2.5950  0.6980  ...  0.3230 -0.4140  0.2532  0.0513  0.8600  1.4250
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
dados #percebemos que o que foi filtrado acima não mudou nd na tabela original
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
dados.rename(columns={'g-0':'g0'}, inplace=True)
dados.rename(columns={'g-1':'g1'}, inplace=True)
dados.rename(columns={'g-2':'g2'}, inplace=True) #rename, como diz o nome, ele renomea a coluna
dados
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#            g2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
dados.query('g0>0')
# Out:
#                  id    tratamento  tempo dose      droga      g0      g1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 6      id_001bd861f     com_droga     24   D2  746ca1f5a  2.0440  1.7000
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133
# ...             ...           ...    ...  ...        ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  a28556d51  0.1420 -0.3696
# 23808  id_fff8c2444     com_droga     72   D1  6c3a459be  0.1608 -1.0500
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
#
#            g2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
import matplotlib.pyplot as plt

dados['tempo'].value_counts().plot.bar() #gráfico de barra
plt.title('Tratamento em função do tempo', fontsize=16)
plt.xlabel('Tempo')
plt.ylabel('Tratamento')
plt.show()

# %% [markdown]
# ## Desafios Aula 01
# Desafio 01: Plotar as 5 últimas linhas da tabela ```.tail()```
#
# Desafio 02: Proporção das classes tratamento. ```.value_counts(normalize = True)``` / ```.map('{:.2%}'.format)``` -> formata em porcentagem
#
# Desafio 03: Procurar na documentação o método query(pandas). ```.query('g0>0')```
#
# Desafio 04: Renomear as colunas tirando o hífen. ```.rename(columns={'g-0':'g0'}, inplace = True)```
#
# Desafio 05: Deixar os gráficos bonitões. (Matplotlib.pyplot) ```plt.title()``` / ```plt.xlabel()``` / ```plt.ylabel()``` / ``` plt.show()```

# %%
dados.rename(columns={'droga':'composto'}, inplace=True) #muda o nome da coluna, inplace faz com que essa mudança seja feita na tabela original
dados.head()
# Out:
#              id tratamento  tempo dose   composto      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
cod_compostos = dados['composto'].value_counts().index[0:5] #aqui estamos vendo quantos tipos de compostos a gente tem e criando um array com os top 5 dos mesmos
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dadosCod_compostos = dados.query('composto in @cod_compostos') #filtra a coluna composto, mostrando apenas os top 5 deles

# %%
import seaborn as sns
sns.set() #utilizar os estilos padroes oferecidos pela seaborn
dadosCod_compostos = dados.query('composto in @cod_compostos')
plt.figure(figsize=(10,8))
ax =sns.countplot(x = 'composto', data = dadosCod_compostos, order = dadosCod_compostos['composto'].value_counts().index) #plota um gráfico, recebe um x,y, também se quiser limitar os dados da coluna como feito acima, em que ele pega apenas os top 5
ax.set_title('Top 5 Compostos', fontsize=20)
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins=100)
plt.show()

# %%
dados.describe()
# Out:
#               tempo            g0            g1            g2           g-3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                 g-4           g-5           g-6           g-7           g-8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %%
dados[['g0','g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g1':'g-771'].describe().T
# Out:
#          count      mean       std     min       25%      50%       75%  \
# g1     23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075
# g2     23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375
# g-5    23814.0 -0.138836  1.179388 -10.000 -0.602225 -0.01565  0.510425
# ...        ...       ...       ...     ...       ...      ...       ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950
#
#           max
# g1      5.039
# g2      8.257
# g-3    10.000
# g-4    10.000
# g-5     7.282
# ...

# %%
dados.loc[:,'g1':'g-771'].describe().T['mean'].hist(bins=50)
plt.show()

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)
plt.show()

# %%
sns.boxplot(x='g0', data=dados)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0',x='tratamento', data=dados)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(dados['g0'], bins=100, kde=True) #bins, aumenta as barras - Kde, faz uma curva "contornando" o histograma
plt.show()

# %% [markdown]
# ## Desafios Aula 02
# Desafio 01: Ordenar o gráfico countplot ```ax =sns.countplot(x = 'composto', data = dadosCod_compostos, order = dadosCod_compostos['composto'].value_counts().index)```
#
# Desafio 02: Melhorar a visualização alterando tamanho da fonte... ```ax.set_title('Top 5 Compostos', fontsize=20)```
#
# Desafio 03: Plotar os histogramas com seaborn ```sns.histplot(dados['g0'])```
#
# Desafio 04: Estudar sobre as estatíticas retornadas no .describe()
